# %% [markdown]
# ## 01 - Importação das Bibliotecas

# %%
import pandas as pd
import os

# %% [markdown]
# ## 02 - Carregando o CSV do Dataset

# %%
caminhoAtual = os.getcwd()
caminhoDataset = os.path.join(caminhoAtual, "..\\dataset\\brasileirao.csv")

# Este dataset foi baixado contendo os dados de jogos ocorridos até o dia 13/05/2025
brasileirao = pd.read_csv(caminhoDataset)

# %% [markdown]
# ## 03 - Analisando os Dados

# %% [markdown]
# ### 03.1 - Extremidades da Tabela

# %%
# Primeiras 5 linhas
brasileirao.head()
# Out:
#   Country   League  Season        Date   Time          Home         Away   HG  \
# 0  Brazil  Serie A    2012  19/05/2012  22:30     Palmeiras   Portuguesa  1.0
# 1  Brazil  Serie A    2012  19/05/2012  22:30  Sport Recife  Flamengo RJ  1.0
# 2  Brazil  Serie A    2012  20/05/2012  01:00   Figueirense      Nautico  2.0
# 3  Brazil  Serie A    2012  20/05/2012  20:00   Botafogo RJ    Sao Paulo  4.0
# 4  Brazil  Serie A    2012  20/05/2012  20:00   Corinthians   Fluminense  0.0
#
#     AG Res  ...  PSCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  BFECH  BFECD  \
# 0  1.0   D  ...  5.25   1.76   3.87   5.31   1.69   3.50   4.90    NaN    NaN
# 1  1.0   D  ...  2.68   2.83   3.42   2.70   2.59   3.23   2.58    NaN    NaN
# 2  1.0   H  ...  6.72   1.67   4.05   7.22   1.59   3.67   5.64    NaN    NaN
# 3  2.0   H  ...  3.15   2.49   3.39   3.15   2.35   3.26   2.84    NaN    NaN
# 4  1.0   A  ...  4.41   1.96   3.53   4.41   1.89   3.33   3.89    NaN    NaN
#
#    BFECA
# 0    NaN
# ...

# %%
# Últimas 5 linhas
brasileirao.tail()
# Out:
#      Country   League  Season        Date   Time          Home           Away  \
# 5015  Brazil  Serie A    2025  11/05/2025  20:00  Sport Recife       Cruzeiro
# 5016  Brazil  Serie A    2025  11/05/2025  21:30   Atletico-MG     Fluminense
# 5017  Brazil  Serie A    2025  11/05/2025  21:30     Palmeiras      Sao Paulo
# 5018  Brazil  Serie A    2025  12/05/2025  00:00   Botafogo RJ  Internacional
# 5019  Brazil  Serie A    2025  13/05/2025  00:00        Santos          Ceara
#
#        HG   AG Res  ...  PSCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  \
# 5015  0.0  4.0   A  ...  3.28   2.63   3.08   3.28   2.50   2.98   3.12
# 5016  3.0  2.0   H  ...  4.56   2.00   3.32   4.60   1.93   3.22   4.40
# 5017  1.0  0.0   H  ...  5.70   1.81   3.46   5.70   1.76   3.33   5.36
# 5018  4.0  0.0   H  ...  5.69   1.93   3.60   5.88   1.72   3.52   5.32
# 5019  0.0  0.0   D  ...  3.35   2.52   3.06   3.60   2.42   2.93   3.35
#
#       BFECH  BFECD  BFECA
# 5015   2.58   3.15    3.3
# ...

# %% [markdown]
# ### 03.02 - Quantidade de Linhas e Colunas

# %%
linhas, colunas = brasileirao.shape
print(f"Esta tabela contém {linhas} linhas e {colunas} colunas")
# Out:
# Esta tabela contém 5020 linhas e 22 colunas

# %% [markdown]
# ### 03.03 - Informações sobre as Colunas (Variáveis)

# %%
brasileirao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5020 entries, 0 to 5019
# Data columns (total 22 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  5020 non-null   object
#  1   League   5020 non-null   object
#  2   Season   5020 non-null   int64
#  3   Date     5020 non-null   object
#  4   Time     5020 non-null   object
#  5   Home     5020 non-null   object
#  6   Away     5020 non-null   object
#  7   HG       5019 non-null   float64
#  8   AG       5019 non-null   float64
#  9   Res      5019 non-null   object
#  10  PSCH     5019 non-null   float64
#  11  PSCD     5019 non-null   float64
#  12  PSCA     5019 non-null   float64
#  13  MaxCH    5020 non-null   float64
#  14  MaxCD    5020 non-null   float64
#  15  MaxCA    5020 non-null   float64
#  16  AvgCH    5020 non-null   float64
#  17  AvgCD    5020 non-null   float64
#  18  AvgCA    5020 non-null   float64
#  19  BFECH    315 non-null    float64
# ...

# %% [markdown]
# ### 03.04 - Classificando as variáveis

# %% [markdown]
# | Variável           | Tipo         | Observação |
# |--------------------|--------------|------------|
# | `Country`          | Qualitativa  | País sede do campeonato |
# | `League`           | Qualitativa  | Nome do campeonato |
# | `Season`           | Qualitativa  | Edição do campeonato |
# | `Date`             | Qualitativa  | Data de um jogo no formato DD/MM/AAAA |
# | `Time`             | Qualitativa  | Horário em que o jogo começou no fuso horário UTC-0 |
# | `Home`             |
# | `Away`             |
# | `HG`               |
# | `AG`               |
# | `Res`              |
# | `PSCH`             |
# | `PSCD`             |
# | `PSCA`             |
# | `MaxCH`            |
# | `MaxCD`            |
# | `MaxCA`            |
# | `AvgCH`            |
# | `AvgCD`            |
# | `AvgCA`            |
# | `BFECH`            |
# | `BFECD`            |
# | `BFECA`            |
